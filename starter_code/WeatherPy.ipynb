# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

#Define empty lists to store values
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

#Looping through cities to make api calls using city as query
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
#Extracting data. Missing data is handled by try and except  
    try:
        
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
    except (KeyError):
        print("City not found. skipping.")
# Out:
# Processing record 1|saint-philippe
# Processing record 2|narsaq
# Processing record 3|faya
# Processing record 4|jamestown
# Processing record 5|fort nelson
# Processing record 6|vanimo
# Processing record 7|port said
# Processing record 8|codrington
# Processing record 9|tagusao
# Processing record 10|gawler
# Processing record 11|new norfolk
# Processing record 12|bluff
# Processing record 13|ulaangom
# Processing record 14|barrow
# City not found. skipping.
# Processing record 15|bredasdorp
# Processing record 16|cape town
# City not found. skipping.
# Processing record 17|saldanha
# Processing record 18|avarua
# Processing record 19|khatanga
# Processing record 20|tutoia
# Processing record 21|padang
# City not found. skipping.
# Processing record 22|vilcun
# Processing record 23|coxim
# Processing record 24|sechura
# Processing record 25|altay
# Processing record 26|paciran
# Processing record 27|busselton
# Processing record 28|port alfred
# City not found. skipping.
# Processing record 29|ushuaia
# Processing record 30|ribeira grande
# Processing record 31|nuuk
# Processing record 32|puerto ayora
# Processing record 33|topolobampo
# Processing record 34|ugoofaaru
# City not found. skipping.
# Processing record 35|arraial do cabo
# Processing record 36|punta arenas
# Processing record 37|rikitea
# Processing record 38|san jose
# Processing record 39|kununurra
# Processing record 40|cherskiy
# Processing record 41|esperance
# Processing record 42|mecca
# Processing record 43|kodiak
# Processing record 44|dikson
# Processing record 45|aksarka
# Processing record 46|kapaa
# Processing record 47|polunochnoye
# Processing record 48|summerland
# Processing record 49|thompson
# Processing record 50|tuktoyaktuk
# Processing record 51|namatanai
# Processing record 52|san cristobal
# City not found. skipping.
# Processing record 53|la ronge
# Processing record 54|norman wells
# City not found. skipping.
# Processing record 55|juba
# Processing record 56|isangel
# Processing record 57|parfenyevo
# Processing record 58|kandry
# Processing record 59|aden
# Processing record 60|longyearbyen
# Processing record 61|vaini
# Processing record 62|ahipara
# Processing record 63|san andres
# Processing record 64|pacific grove
# Processing record 65|mount darwin
# Processing record 66|deputatskiy
# Processing record 67|mataura
# Processing record 68|concepcion del uruguay
# Processing record 69|dalaba
# Processing record 70|clyde river
# Processing record 71|erenhot
# Processing record 72|goderich
# Processing record 73|sitka
# Processing record 74|hithadhoo
# Processing record 75|zemio
# Processing record 76|san patricio
# Processing record 77|leningradskiy
# Processing record 78|mon
# Processing record 79|lorengau
# Processing record 80|bethel
# Processing record 81|ndele
# Processing record 82|pangkalanbuun
# Processing record 83|qaanaaq
# Processing record 84|ponta do sol
# Processing record 85|witham
# Processing record 86|fort beaufort
# Processing record 87|cayenne
# Processing record 88|hermanus
# Processing record 89|saint-joseph
# Processing record 90|severo-kurilsk
# Processing record 91|iqaluit
# Processing record 92|lata
# Processing record 93|atuona
# Processing record 94|seymchan
# Processing record 95|felipe carrillo puerto
# City not found. skipping.
# Processing record 96|cidreira
# Processing record 97|nikolskoye
# Processing record 98|nemuro
# Processing record 99|salinas
# City not found. skipping.
# Processing record 100|luba
# Processing record 101|krasnaya gora
# Processing record 102|cabo san lucas
# Processing record 103|champerico
# Processing record 104|mwanza
# Processing record 105|broken hill
# Processing record 106|upernavik
# Processing record 107|porto seguro
# Processing record 108|cabedelo
# Processing record 109|bathsheba
# Processing record 110|conceicao do coite
# Processing record 111|lulea
# Processing record 112|sao joao da barra
# Processing record 113|banda aceh
# Processing record 114|collie
# Processing record 115|port elizabeth
# Processing record 116|vestmannaeyjar
# Processing record 117|kalengwa
# Processing record 118|butaritari
# Processing record 119|mosquera
# Processing record 120|albany
# Processing record 121|fairbanks
# Processing record 122|saint george
# Processing record 123|moerai
# Processing record 124|pevek
# Processing record 125|jalingo
# Processing record 126|ixtapa
# City not found. skipping.
# City not found. skipping.
# Processing record 127|sacele
# Processing record 128|bolshaya martynovka
# Processing record 129|lompoc
# Processing record 130|husavik
# Processing record 131|srednyaya yelyuzan
# Processing record 132|talcahuano
# Processing record 133|srednekolymsk
# Processing record 134|abbotsford
# Processing record 135|sioux lookout
# Processing record 136|kaeo
# Processing record 137|tavrichanka
# Processing record 138|conde
# Processing record 139|east london
# Processing record 140|bonthe
# Processing record 141|jumla
# Processing record 142|chokwe
# Processing record 143|georgetown
# Processing record 144|edd
# Processing record 145|udachnyy
# Processing record 146|san juan
# Processing record 147|northam
# Processing record 148|tucuma
# Processing record 149|bilma
# Processing record 150|college
# Processing record 151|koluszki
# Processing record 152|shawnee
# Processing record 153|kinsale
# Processing record 154|ekhabi
# City not found. skipping.
# Processing record 155|sile
# Processing record 156|aklavik
# Processing record 157|mongar
# Processing record 158|kaitangata
# City not found. skipping.
# Processing record 159|provideniya
# Processing record 160|ust-kuyga
# Processing record 161|veraval
# Processing record 162|saskylakh
# Processing record 163|bambous virieux
# Processing record 164|nanortalik
# Processing record 165|hualmay
# Processing record 166|iquique
# Processing record 167|souillac
# Processing record 168|spearfish
# Processing record 169|port hardy
# Processing record 170|verkhoyansk
# Processing record 171|turukhansk
# Processing record 172|smithers
# Processing record 173|mao
# Processing record 174|hilo
# Processing record 175|qingdao
# Processing record 176|severo-yeniseyskiy
# Processing record 177|namuac
# Processing record 178|asyut
# Processing record 179|paranaiba
# Processing record 180|sept-iles
# Processing record 181|banyo
# Processing record 182|waipawa
# Processing record 183|le port
# Processing record 184|buala
# Processing record 185|monrovia
# Processing record 186|martapura
# Processing record 187|westport
# Processing record 188|tomakomai
# Processing record 189|santa rosa
# Processing record 190|carnarvon
# Processing record 191|sambava
# Processing record 192|tommot
# Processing record 193|longhua
# Processing record 194|airai
# Processing record 195|san pietro vernotico
# Processing record 196|gambela
# Processing record 197|matagami
# Processing record 198|paracuru
# Processing record 199|victoria
# Processing record 200|kruisfontein
# Processing record 201|cardston
# Processing record 202|hobart
# Processing record 203|beroroha
# Processing record 204|pecos
# Processing record 205|salalah
# Processing record 206|palana
# Processing record 207|key largo
# Processing record 208|lalmohan
# Processing record 209|kudahuvadhoo
# Processing record 210|aswan
# City not found. skipping.
# Processing record 211|san luis
# Processing record 212|chokurdakh
# Processing record 213|arlit
# City not found. skipping.
# Processing record 214|karratha
# Processing record 215|tatawin
# Processing record 216|chuy
# Processing record 217|tamiahua
# Processing record 218|sovetskiy
# Processing record 219|makakilo city
# Processing record 220|ihtiman
# Processing record 221|mongoumba
# Processing record 222|krasnoselkup
# Processing record 223|bandarbeyla
# Processing record 224|kavieng
# Processing record 225|troutdale
# Processing record 226|saint-pierre
# Processing record 227|klaksvik
# Processing record 228|luderitz
# Processing record 229|kraksaan
# Processing record 230|gamba
# Processing record 231|lebu
# Processing record 232|byron bay
# Processing record 233|jieshi
# Processing record 234|yellowknife
# Processing record 235|nyurba
# Processing record 236|olafsvik
# Processing record 237|yakeshi
# Processing record 238|bac lieu
# Processing record 239|panguiranan
# Processing record 240|kenai
# Processing record 241|kastamonu
# Processing record 242|balatan
# Processing record 243|sholokhove
# Processing record 244|bonavista
# Processing record 245|vardo
# Processing record 246|zhanakorgan
# Processing record 247|puerto leguizamo
# City not found. skipping.
# Processing record 248|castro
# City not found. skipping.
# Processing record 249|paamiut
# Processing record 250|bama
# Processing record 251|ostrovnoy
# Processing record 252|hasaki
# City not found. skipping.
# Processing record 253|zhigansk
# Processing record 254|bud
# Processing record 255|svetlogorsk
# Processing record 256|berlevag
# Processing record 257|queenstown
# Processing record 258|torbay
# Processing record 259|constitucion
# Processing record 260|szczytno
# Processing record 261|oussouye
# Processing record 262|las vegas
# Processing record 263|sretensk
# Processing record 264|vaitape
# Processing record 265|omboue
# Processing record 266|tasiilaq
# Processing record 267|ancud
# Processing record 268|maragogi
# Processing record 269|gibara
# Processing record 270|kajiado
# Processing record 271|mayor pablo lagerenza
# Processing record 272|katsuura
# City not found. skipping.
# Processing record 273|strezhevoy
# Processing record 274|biltine
# Processing record 275|ilulissat
# Processing record 276|port blair
# Processing record 277|digoin
# City not found. skipping.
# City not found. skipping.
# Processing record 278|anadyr
# Processing record 279|hornepayne
# Processing record 280|soe
# Processing record 281|pundaguitan
# Processing record 282|tura
# City not found. skipping.
# Processing record 283|svoboda nad upou
# Processing record 284|tiksi
# Processing record 285|lawton
# Processing record 286|eyl
# Processing record 287|los llanos de aridane
# Processing record 288|hay river
# Processing record 289|sao filipe
# Processing record 290|newport
# Processing record 291|mangan
# Processing record 292|olinda
# Processing record 293|boa vista
# Processing record 294|riyadh
# Processing record 295|touros
# Processing record 296|kahului
# Processing record 297|nerchinskiy zavod
# Processing record 298|pitimbu
# Processing record 299|zhuanghe
# Processing record 300|faanui
# Processing record 301|tautira
# Processing record 302|mogadishu
# Processing record 303|lagoa
# Processing record 304|bergen
# Processing record 305|mateare
# Processing record 306|fortuna
# Processing record 307|wajid
# Processing record 308|alcaniz
# Processing record 309|dunedin
# Processing record 310|inverness
# Processing record 311|nizhniy odes
# Processing record 312|raga
# Processing record 313|reynosa
# Processing record 314|hamilton
# Processing record 315|bambanglipuro
# Processing record 316|hofn
# Processing record 317|mugur-aksy
# Processing record 318|zyryanka
# Processing record 319|thanh hoa
# Processing record 320|shingu
# Processing record 321|lalawigan
# Processing record 322|grajau
# Processing record 323|puerto baquerizo moreno
# Processing record 324|geraldton
# Processing record 325|sinjar
# Processing record 326|imbituba
# Processing record 327|myskhako
# Processing record 328|namibe
# Processing record 329|hambantota
# Processing record 330|kaputa
# City not found. skipping.
# Processing record 331|margate
# Processing record 332|barabai
# Processing record 333|sirumugai
# Processing record 334|cockburn town
# Processing record 335|sangar
# Processing record 336|gat
# Processing record 337|kismayo
# Processing record 338|grootfontein
# Processing record 339|hope mills
# Processing record 340|salinopolis
# Processing record 341|jiaohe
# Processing record 342|cape canaveral
# Processing record 343|santa maria
# Processing record 344|nova odesa
# City not found. skipping.
# Processing record 345|tuatapere
# Processing record 346|dubna
# Processing record 347|onda
# City not found. skipping.
# Processing record 348|kralendijk
# Processing record 349|seoul
# Processing record 350|springdale
# Processing record 351|arman
# Processing record 352|porterville
# Processing record 353|sehithwa
# Processing record 354|ndende
# City not found. skipping.
# Processing record 355|sabang
# Processing record 356|iwanai
# Processing record 357|finschhafen
# Processing record 358|tuy hoa
# Processing record 359|alappuzha
# Processing record 360|takab
# Processing record 361|kemijarvi
# Processing record 362|tocopilla
# Processing record 363|kalmunai
# City not found. skipping.
# Processing record 364|conselheiro lafaiete
# Processing record 365|kodinsk
# Processing record 366|umm lajj
# City not found. skipping.
# City not found. skipping.
# Processing record 367|sinnamary
# Processing record 368|snasa
# Processing record 369|clarence town
# City not found. skipping.
# Processing record 370|hovd
# Processing record 371|bahia honda
# Processing record 372|nanzhou
# Processing record 373|samarai
# Processing record 374|nishihara
# Processing record 375|ballina
# Processing record 376|burnie
# Processing record 377|mpika
# Processing record 378|heide
# Processing record 379|aginskoye
# Processing record 380|a coruna
# Processing record 381|noumea
# Processing record 382|maniitsoq
# Processing record 383|bontang
# Processing record 384|loutros
# Processing record 385|douglas
# Processing record 386|ayan
# Processing record 387|kavaratti
# Processing record 388|marienburg
# Processing record 389|menzelinsk
# Processing record 390|half moon bay
# Processing record 391|grand gaube
# Processing record 392|teguise
# Processing record 393|the valley
# Processing record 394|belgaum
# Processing record 395|aldama
# Processing record 396|ishigaki
# Processing record 397|san pedro
# Processing record 398|lingsugur
# Processing record 399|rabo de peixe
# Processing record 400|orange
# Processing record 401|homer
# Processing record 402|saint anthony
# Processing record 403|amet
# City not found. skipping.
# Processing record 404|ottumwa
# Processing record 405|ust-nera
# Processing record 406|bengkulu
# Processing record 407|mungeli
# Processing record 408|bairiki
# Processing record 409|marawi
# Processing record 410|uddevalla
# Processing record 411|ifanadiana
# Processing record 412|port-gentil
# Processing record 413|mount gambier
# Processing record 414|adrar
# Processing record 415|ewa beach
# Processing record 416|gravdal
# Processing record 417|port hedland
# Processing record 418|arvin
# Processing record 419|vostok
# City not found. skipping.
# Processing record 420|neiafu
# Processing record 421|iralaya
# City not found. skipping.
# Processing record 422|cassilandia
# City not found. skipping.
# City not found. skipping.
# Processing record 423|verkhnyaya inta
# Processing record 424|barahona
# Processing record 425|morondava
# Processing record 426|colonelganj
# Processing record 427|manzanillo
# Processing record 428|abbeville
# Processing record 429|inuvik
# Processing record 430|mahebourg
# Processing record 431|candido mendes
# Processing record 432|norfolk
# City not found. skipping.
# Processing record 433|mount isa
# Processing record 434|talnakh
# Processing record 435|saquarema
# Processing record 436|cairns
# Processing record 437|chifeng
# Processing record 438|sompeta
# Processing record 439|malaya serdoba
# Processing record 440|vao
# Processing record 441|bereda
# Processing record 442|maumere
# Processing record 443|la paz
# City not found. skipping.
# Processing record 444|olden
# Processing record 445|nizwa
# Processing record 446|sharan
# Processing record 447|merritt
# Processing record 448|rawson
# Processing record 449|sakakah
# Processing record 450|baie-comeau
# Processing record 451|oranjestad
# Processing record 452|hit
# Processing record 453|vadso
# Processing record 454|wanning
# Processing record 455|shimoda
# Processing record 456|teahupoo
# Processing record 457|komsomolskiy
# Processing record 458|belmonte
# Processing record 459|xining
# Processing record 460|youghal
# Processing record 461|aitape
# Processing record 462|coquimbo
# Processing record 463|sistranda
# Processing record 464|san vicente
# Processing record 465|mar del plata
# Processing record 466|rosarito
# Processing record 467|inta
# Processing record 468|eirunepe
# Processing record 469|ponerihouen
# Processing record 470|merauke
# Processing record 471|kurkino
# Processing record 472|upington
# Processing record 473|sosnovo
# City not found. skipping.
# Processing record 474|chengde
# Processing record 475|juruti
# Processing record 476|moree
# Processing record 477|encheng
# City not found. skipping.
# City not found. skipping.
# Processing record 478|glendive
# Processing record 479|yerbogachen
# Processing record 480|bar harbor
# Processing record 481|hilton head island
# Processing record 482|nurota
# City not found. skipping.
# Processing record 483|biak
# Processing record 484|yilan
# Processing record 485|dafeng
# Processing record 486|zhangye
# Processing record 487|yevlax
# Processing record 488|mitchell
# Processing record 489|novaya ladoga
# Processing record 490|hobyo
# Processing record 491|yulara
# Processing record 492|tazmalt
# Processing record 493|fort-shevchenko
# Processing record 494|emerald
# Processing record 495|sheridan
# Processing record 496|norrtalje
# Processing record 497|road town
# City not found. skipping.
# Processing record 498|weatherford
# Processing record 499|flinders
# City not found. skipping.
# Processing record 500|banamba
# Processing record 501|north bend
# Processing record 502|saryozek
# Processing record 503|camacha
# Processing record 504|alekseyevsk
# Processing record 505|shelburne
# Processing record 506|ahuimanu
# Processing record 507|tanout
# Processing record 508|polyarnyy
# Processing record 509|qurayyat
# Processing record 510|portland
# Processing record 511|cuencame
# City not found. skipping.
# Processing record 512|buchanan
# Processing record 513|mezen
# Processing record 514|egvekinot
# Processing record 515|amursk
# City not found. skipping.
# Processing record 516|yaan
# Processing record 517|mnogovershinnyy
# Processing record 518|port macquarie
# Processing record 519|villa constitucion
# Processing record 520|whitehorse
# Processing record 521|sterling
# Processing record 522|teya
# Processing record 523|plaridel
# Processing record 524|kidal
# Processing record 525|auki
# Processing record 526|aberdeen
# Processing record 527|amazar
# Processing record 528|soma
# Processing record 529|guerrero negro
# City not found. skipping.
# Processing record 530|jalu
# Processing record 531|baruun-urt
# City not found. skipping.
# Processing record 532|saint-augustin
# Processing record 533|borogontsy
# Processing record 534|bozova
# Processing record 535|payo
# Processing record 536|shaowu
# Processing record 537|nalut
# Processing record 538|wejherowo
# Processing record 539|stavelot
# Processing record 540|pamanukan
# Processing record 541|jiazi
# Processing record 542|gallatin
# Processing record 543|gobabis
# Processing record 544|presidente epitacio
# Processing record 545|eitorf
# Processing record 546|les cayes
# Processing record 547|nara
# Processing record 548|acapulco
# Processing record 549|saurimo
# Processing record 550|tholen
# Processing record 551|ulaanbaatar
# City not found. skipping.
# Processing record 552|peterhead
# Processing record 553|de land
# Processing record 554|anloga
# Processing record 555|coihaique
# Processing record 556|presidencia roque saenz pena
# Processing record 557|rizhao
# Processing record 558|poum
# Processing record 559|talara
# Processing record 560|dharchula
# Processing record 561|itarema
# Processing record 562|sonoita
# Processing record 563|sungairaya
# Processing record 564|carapegua
# Processing record 565|haines junction
# City not found. skipping.
# Processing record 566|bom jesus
# Processing record 567|aszalo
# Processing record 568|aksha
# Processing record 569|assiniboia
# Processing record 570|zabol
# Processing record 571|ambulu
# Processing record 572|banjarmasin
# Processing record 573|haimen
# Processing record 574|kingaroy
# Processing record 575|ponta delgada
# Processing record 576|umm kaddadah
# Processing record 577|marfino
# Processing record 578|samfya
# Processing record 579|taoudenni
# Processing record 580|evensk
# Processing record 581|opuwo
# Processing record 582|kartaly
# Processing record 583|tabuk

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating city dataframe
city_df = pd.DataFrame({"City":city_name, 
                        "Cloudiness":cloudiness, 
                        "Country":country, 
                        "Date":date, 
                        "Humidity":humidity,
                        "Lat":lat,
                        "Lng":lng,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed
                                         })
city_df = city_df.rename_axis('City ID')

#Exporting data to csv
city_df.to_csv("../output_data/city.csv")

#Displaying dataframe
city_df.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity      Lat  \
# City ID
# 0        Saint-Philippe           0      RE  04/24/2021        73 -21.3585
# 1                Narsaq          90      GL  04/24/2021        32  60.9167
# 2                  Faya          40      SA  04/24/2021        59  18.3851
# 3             Jamestown          90      US  04/24/2021        53  42.0970
# 4           Fort Nelson          20      CA  04/24/2021        33  58.8053
#
#               Lng  Max Temp  Wind Speed
# City ID
# 0         55.7679      79.0       26.46
# 1        -46.0500      51.8       34.52
# 2         42.4509      64.4        3.53
# 3        -79.2353      48.2        5.75
# 4       -122.7002      41.0        4.61

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.count()
# Out:
# City          583
# Cloudiness    583
# Country       583
# Date          583
# Humidity      583
# Lat           583
# Lng           583
# Max Temp      583
# Wind Speed    583
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter( city_df["Lat"], city_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(city_df["Lat"], city_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(city_df["Lat"], city_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(city_df["Lat"], city_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = city_df.loc[city_df["Lat"] >= 0]
southern_hemisphere = city_df.loc[city_df["Lat"] < 0]

# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
