# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

#Define empty lists to store values
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

#Looping through cities to make api calls using city as query
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
#Extracting data. Missing data is handled by try and except  
    try:
        
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
    except (KeyError):
        print("City not found. skipping.")
# Out:
# Processing record 1|avarua
# Processing record 2|khudumelapye
# City not found. skipping.
# Processing record 3|kapaa
# Processing record 4|kodiak
# Processing record 5|kavaratti
# Processing record 6|ati
# Processing record 7|vaini
# Processing record 8|ust-kan
# Processing record 9|saldanha
# Processing record 10|ushuaia
# Processing record 11|butaritari
# Processing record 12|paamiut
# Processing record 13|broome
# Processing record 14|albany
# Processing record 15|anori
# City not found. skipping.
# Processing record 16|sabha
# Processing record 17|geraldton
# Processing record 18|nuuk
# Processing record 19|cape town
# Processing record 20|rikitea
# City not found. skipping.
# Processing record 21|puerto carreno
# Processing record 22|kuito
# Processing record 23|mafinga
# Processing record 24|port-gentil
# Processing record 25|hobart
# Processing record 26|punta arenas
# Processing record 27|atuona
# Processing record 28|flin flon
# Processing record 29|carnarvon
# Processing record 30|tasiilaq
# Processing record 31|sao jose da coroa grande
# Processing record 32|methoni
# City not found. skipping.
# Processing record 33|kimbe
# City not found. skipping.
# Processing record 34|katsuura
# Processing record 35|bethel
# Processing record 36|teguldet
# Processing record 37|thompson
# Processing record 38|mataura
# Processing record 39|souillac
# City not found. skipping.
# Processing record 40|shepsi
# Processing record 41|anadyr
# Processing record 42|qaanaaq
# Processing record 43|fortuna
# Processing record 44|castro
# Processing record 45|nikolskoye
# Processing record 46|jaypur
# Processing record 47|jamestown
# Processing record 48|ozernovskiy
# Processing record 49|salalah
# Processing record 50|saint george
# Processing record 51|hervey bay
# Processing record 52|sao filipe
# Processing record 53|tiksi
# Processing record 54|santa isabel do rio negro
# Processing record 55|henties bay
# Processing record 56|bilibino
# Processing record 57|faanui
# Processing record 58|bluff
# Processing record 59|san cristobal
# Processing record 60|kuopio
# Processing record 61|bambous virieux
# City not found. skipping.
# Processing record 62|longyearbyen
# Processing record 63|comodoro rivadavia
# Processing record 64|manggar
# Processing record 65|kysyl-syr
# Processing record 66|sorkjosen
# Processing record 67|busselton
# Processing record 68|antofagasta
# Processing record 69|dicabisagan
# Processing record 70|khatanga
# Processing record 71|ostrovnoy
# Processing record 72|ponta do sol
# Processing record 73|torbay
# Processing record 74|hamilton
# Processing record 75|damietta
# City not found. skipping.
# Processing record 76|boa vista
# Processing record 77|siocon
# City not found. skipping.
# Processing record 78|vila velha
# Processing record 79|mar del plata
# Processing record 80|hilo
# Processing record 81|rumonge
# Processing record 82|san jeronimo
# Processing record 83|hermanus
# Processing record 84|esperance
# Processing record 85|arraial do cabo
# Processing record 86|samarai
# Processing record 87|sitka
# Processing record 88|caravelas
# Processing record 89|khasan
# Processing record 90|dingle
# Processing record 91|cidreira
# Processing record 92|krutinka
# City not found. skipping.
# Processing record 93|athabasca
# Processing record 94|arlit
# Processing record 95|santa cruz de tenerife
# Processing record 96|airai
# Processing record 97|collie
# Processing record 98|carballo
# Processing record 99|xingyi
# Processing record 100|hambantota
# Processing record 101|pacific grove
# Processing record 102|tagusao
# Processing record 103|bathsheba
# Processing record 104|pochutla
# Processing record 105|ewa beach
# Processing record 106|akureyri
# Processing record 107|roald
# Processing record 108|pangnirtung
# Processing record 109|tessalit
# Processing record 110|gwadar
# Processing record 111|mogadishu
# Processing record 112|kamina
# Processing record 113|grindavik
# Processing record 114|new norfolk
# Processing record 115|hithadhoo
# City not found. skipping.
# Processing record 116|takahashi
# City not found. skipping.
# Processing record 117|itoman
# Processing record 118|vangaindrano
# Processing record 119|labuhan
# Processing record 120|chokurdakh
# Processing record 121|bosaso
# Processing record 122|porto novo
# Processing record 123|takoradi
# Processing record 124|shinpokh
# Processing record 125|kieta
# Processing record 126|klaksvik
# Processing record 127|pinega
# Processing record 128|ancud
# Processing record 129|santa rosa
# Processing record 130|lashio
# Processing record 131|chapais
# Processing record 132|puerto ayora
# Processing record 133|cherskiy
# Processing record 134|aconibe
# Processing record 135|pontes e lacerda
# Processing record 136|barrow
# Processing record 137|clyde river
# Processing record 138|beringovskiy
# Processing record 139|karratha
# Processing record 140|tarakan
# Processing record 141|gigmoto
# Processing record 142|davidson
# Processing record 143|tsumeb
# Processing record 144|kahului
# Processing record 145|port alfred
# Processing record 146|manta
# Processing record 147|pathein
# Processing record 148|pandan
# Processing record 149|si chiang mai
# Processing record 150|vanimo
# Processing record 151|cayenne
# Processing record 152|lebu
# Processing record 153|biak
# Processing record 154|tupik
# Processing record 155|ponta delgada
# Processing record 156|am timan
# Processing record 157|tuktoyaktuk
# Processing record 158|port elizabeth
# Processing record 159|eger
# Processing record 160|hofn
# Processing record 161|borogontsy
# City not found. skipping.
# Processing record 162|xining
# Processing record 163|yellowknife
# Processing record 164|mahebourg
# Processing record 165|matara
# Processing record 166|ilulissat
# Processing record 167|sorland
# Processing record 168|olafsvik
# Processing record 169|marica
# Processing record 170|atherton
# Processing record 171|ulladulla
# Processing record 172|victoria
# Processing record 173|jieshi
# Processing record 174|chuy
# Processing record 175|narsaq
# Processing record 176|hobyo
# Processing record 177|chase
# Processing record 178|trincomalee
# Processing record 179|bredasdorp
# Processing record 180|ambulu
# Processing record 181|north bend
# Processing record 182|scarborough
# Processing record 183|bandarbeyla
# Processing record 184|mount gambier
# Processing record 185|dikson
# Processing record 186|najran
# Processing record 187|east london
# Processing record 188|cotusca
# Processing record 189|aklavik
# Processing record 190|lagoa
# Processing record 191|troutdale
# Processing record 192|ko samui
# Processing record 193|danszentmiklos
# City not found. skipping.
# Processing record 194|vardo
# Processing record 195|tiznit
# Processing record 196|pacasmayo
# Processing record 197|iqaluit
# Processing record 198|kijang
# Processing record 199|lasa
# Processing record 200|saskylakh
# Processing record 201|vostok
# Processing record 202|pedasi
# Processing record 203|mayo
# Processing record 204|koslan
# Processing record 205|taman
# City not found. skipping.
# Processing record 206|muros
# Processing record 207|takanosu
# Processing record 208|orlik
# Processing record 209|isangel
# City not found. skipping.
# Processing record 210|igarka
# Processing record 211|nzerekore
# Processing record 212|bealanana
# Processing record 213|edinburg
# City not found. skipping.
# Processing record 214|agadir
# City not found. skipping.
# Processing record 215|shingu
# City not found. skipping.
# Processing record 216|awjilah
# Processing record 217|havre-saint-pierre
# Processing record 218|wewak
# Processing record 219|coquimbo
# Processing record 220|tual
# Processing record 221|odweyne
# Processing record 222|fare
# Processing record 223|sosua
# Processing record 224|trairi
# Processing record 225|ulaangom
# Processing record 226|chapleau
# Processing record 227|saint-philippe
# Processing record 228|brae
# Processing record 229|dzhebariki-khaya
# Processing record 230|bela
# Processing record 231|provideniya
# Processing record 232|terney
# Processing record 233|alofi
# Processing record 234|saint-francois
# Processing record 235|coihaique
# Processing record 236|loudeac
# Processing record 237|kyzyl-suu
# Processing record 238|bengkulu
# Processing record 239|mae chan
# Processing record 240|waddan
# Processing record 241|sosnovka
# Processing record 242|makakilo city
# Processing record 243|tuatapere
# Processing record 244|baruun-urt
# Processing record 245|lavrentiya
# City not found. skipping.
# Processing record 246|bria
# Processing record 247|jiaojiang
# Processing record 248|port blair
# Processing record 249|dudinka
# City not found. skipping.
# Processing record 250|ahipara
# Processing record 251|riyadh
# Processing record 252|nanortalik
# Processing record 253|keskin
# Processing record 254|aksarka
# Processing record 255|korla
# Processing record 256|farsund
# Processing record 257|rio grande
# Processing record 258|rio gallegos
# Processing record 259|ratnagiri
# Processing record 260|canico
# Processing record 261|dunda
# Processing record 262|lusambo
# Processing record 263|louis trichardt
# Processing record 264|luderitz
# Processing record 265|kerema
# Processing record 266|lazarev
# Processing record 267|kibaya
# Processing record 268|neiafu
# Processing record 269|pontianak
# Processing record 270|adrar
# City not found. skipping.
# Processing record 271|yulara
# Processing record 272|zaysan
# City not found. skipping.
# Processing record 273|coari
# Processing record 274|chiang rai
# Processing record 275|sabinas
# Processing record 276|puro
# Processing record 277|barcelos
# Processing record 278|marawi
# Processing record 279|georgetown
# Processing record 280|ambilobe
# Processing record 281|deputatskiy
# Processing record 282|mackay
# Processing record 283|charyshskoye
# Processing record 284|arbazh
# Processing record 285|voh
# Processing record 286|trelew
# Processing record 287|touros
# Processing record 288|nome
# Processing record 289|cedar city
# Processing record 290|zhigansk
# Processing record 291|viedma
# Processing record 292|kolokani
# Processing record 293|shenjiamen
# Processing record 294|chyhyryn
# Processing record 295|kavieng
# Processing record 296|capao bonito
# City not found. skipping.
# Processing record 297|mala
# City not found. skipping.
# Processing record 298|shimoda
# Processing record 299|puerto del rosario
# Processing record 300|juneau
# Processing record 301|hornepayne
# Processing record 302|ca mau
# Processing record 303|krasnyy chikoy
# City not found. skipping.
# Processing record 304|asau
# City not found. skipping.
# Processing record 305|aurillac
# Processing record 306|moose factory
# Processing record 307|saint-augustin
# Processing record 308|kaeo
# Processing record 309|port hardy
# City not found. skipping.
# Processing record 310|manono
# Processing record 311|vila franca do campo
# City not found. skipping.
# Processing record 312|lakatoro
# Processing record 313|tongren
# Processing record 314|miranda
# City not found. skipping.
# Processing record 315|wanning
# Processing record 316|ribeira brava
# Processing record 317|acapulco
# Processing record 318|rocha
# City not found. skipping.
# Processing record 319|andenes
# Processing record 320|lorengau
# Processing record 321|necochea
# Processing record 322|gidole
# Processing record 323|cherdyn
# Processing record 324|vila do maio
# Processing record 325|conde
# Processing record 326|alice springs
# Processing record 327|grahamstown
# Processing record 328|nagato
# Processing record 329|monrovia
# Processing record 330|pampierstad
# Processing record 331|udachnyy
# Processing record 332|yar-sale
# Processing record 333|taseyevo
# Processing record 334|vestmannaeyjar
# Processing record 335|guerrero negro
# Processing record 336|petropavlovsk-kamchatskiy
# Processing record 337|valparaiso
# Processing record 338|marienburg
# Processing record 339|ipixuna
# Processing record 340|grand-santi
# Processing record 341|san patricio
# Processing record 342|tanout
# City not found. skipping.
# Processing record 343|flinders
# Processing record 344|abay
# Processing record 345|bokovskaya
# Processing record 346|ust-nera
# Processing record 347|davila
# Processing record 348|sorong
# Processing record 349|quatre cocos
# Processing record 350|moundsville
# City not found. skipping.
# Processing record 351|shurugwi
# Processing record 352|bud
# Processing record 353|vikulovo
# Processing record 354|misratah
# Processing record 355|bagdarin
# Processing record 356|mayumba
# City not found. skipping.
# Processing record 357|tsiroanomandidy
# Processing record 358|chunskiy
# Processing record 359|bouar
# Processing record 360|tazovskiy
# Processing record 361|pombas
# Processing record 362|sabang
# Processing record 363|zhaotong
# Processing record 364|broken hill
# Processing record 365|kamaishi
# Processing record 366|benito juarez
# Processing record 367|ribeira grande
# Processing record 368|safranbolu
# Processing record 369|constitucion
# Processing record 370|storm lake
# City not found. skipping.
# Processing record 371|erenhot
# Processing record 372|hondo
# Processing record 373|ust-kuyga
# Processing record 374|seymchan
# City not found. skipping.
# City not found. skipping.
# Processing record 375|natal
# Processing record 376|dabakala
# Processing record 377|ourossogui
# Processing record 378|severo-kurilsk
# Processing record 379|sept-iles
# Processing record 380|leningradskiy
# Processing record 381|alagir
# Processing record 382|namtsy
# Processing record 383|manuk mangkaw
# Processing record 384|skibbereen
# City not found. skipping.
# Processing record 385|neryungri
# Processing record 386|lata
# Processing record 387|ivaipora
# Processing record 388|petawawa
# Processing record 389|khoy
# Processing record 390|inver grove heights
# Processing record 391|ostersund
# Processing record 392|laguna
# Processing record 393|cap-aux-meules
# Processing record 394|kerman
# Processing record 395|upernavik
# Processing record 396|carutapera
# Processing record 397|channel-port aux basques
# Processing record 398|alta floresta
# Processing record 399|abashiri
# Processing record 400|villavicencio
# Processing record 401|smithers
# Processing record 402|kawalu
# Processing record 403|egvekinot
# Processing record 404|portland
# Processing record 405|chalinze
# Processing record 406|eyl
# Processing record 407|naze
# Processing record 408|kushmurun
# Processing record 409|boddam
# Processing record 410|gizo
# Processing record 411|bam
# City not found. skipping.
# Processing record 412|locri
# Processing record 413|darab
# Processing record 414|kidal
# Processing record 415|pisco
# Processing record 416|ilava
# Processing record 417|kamenka
# Processing record 418|capoterra
# Processing record 419|santa maria
# Processing record 420|miri
# Processing record 421|pevek
# Processing record 422|marsh harbour
# Processing record 423|kiunga
# Processing record 424|kudahuvadhoo
# Processing record 425|ajdabiya
# Processing record 426|issaquah
# City not found. skipping.
# Processing record 427|tromso
# Processing record 428|puerto colombia
# Processing record 429|kananga
# Processing record 430|taybad
# Processing record 431|calbuco
# Processing record 432|springdale
# Processing record 433|concepcion del oro
# Processing record 434|salinas
# Processing record 435|hasaki
# Processing record 436|fairbanks
# Processing record 437|miramar
# City not found. skipping.
# Processing record 438|beatrice
# Processing record 439|marsa matruh
# Processing record 440|dalvik
# Processing record 441|guangyuan
# Processing record 442|haradok
# Processing record 443|baykit
# Processing record 444|vysokogornyy
# Processing record 445|sompeta
# Processing record 446|jumla
# Processing record 447|sapele
# Processing record 448|kuusamo
# Processing record 449|talnakh
# Processing record 450|smoky lake
# Processing record 451|robertsport
# Processing record 452|quang ngai
# Processing record 453|grand gaube
# Processing record 454|port macquarie
# Processing record 455|lahaina
# Processing record 456|anage
# Processing record 457|manado
# Processing record 458|kruisfontein
# Processing record 459|tuy hoa
# Processing record 460|sur
# Processing record 461|nishihara
# Processing record 462|xiongzhou
# Processing record 463|venkatagiri
# Processing record 464|qasigiannguit
# City not found. skipping.
# City not found. skipping.
# Processing record 465|half moon bay
# Processing record 466|placido de castro
# Processing record 467|pimentel
# Processing record 468|nabire
# Processing record 469|shaoguan
# Processing record 470|srednekolymsk
# Processing record 471|nefteyugansk
# Processing record 472|pauini
# Processing record 473|caramay
# Processing record 474|sandusky
# Processing record 475|riachao do jacuipe
# City not found. skipping.
# City not found. skipping.
# Processing record 476|ballangen
# Processing record 477|chincha alta
# Processing record 478|lewisporte
# Processing record 479|bonavista
# Processing record 480|alyangula
# Processing record 481|riviere-au-renard
# Processing record 482|inhambane
# Processing record 483|goundam
# Processing record 484|hermosillo
# Processing record 485|aneho
# Processing record 486|san vicente
# Processing record 487|bad freienwalde
# Processing record 488|christchurch
# City not found. skipping.
# Processing record 489|urengoy
# Processing record 490|samandag
# Processing record 491|villazon
# Processing record 492|sola
# Processing record 493|horsham
# Processing record 494|guanare
# Processing record 495|zyryanka
# Processing record 496|hami
# Processing record 497|waipawa
# Processing record 498|ixtapa
# City not found. skipping.
# Processing record 499|morehead
# Processing record 500|chute-aux-outardes
# Processing record 501|namibe
# Processing record 502|kulhudhuffushi
# Processing record 503|agirish
# Processing record 504|nhulunbuy
# Processing record 505|karimnagar
# Processing record 506|sidney
# Processing record 507|sabya
# Processing record 508|santiago de cuba
# Processing record 509|namatanai
# Processing record 510|kez
# Processing record 511|abha
# Processing record 512|klyuchi
# Processing record 513|la romana
# Processing record 514|japura
# Processing record 515|the valley
# Processing record 516|dukat
# Processing record 517|harper
# Processing record 518|ternuvate
# Processing record 519|nova olinda do norte
# Processing record 520|ajuchitlan
# Processing record 521|sopur
# Processing record 522|mersin
# Processing record 523|bubaque
# Processing record 524|amahai
# Processing record 525|vestmanna
# Processing record 526|port hedland
# Processing record 527|lavumisa
# Processing record 528|taoudenni
# Processing record 529|riachao das neves
# Processing record 530|lubango
# Processing record 531|correia pinto
# Processing record 532|mayor pablo lagerenza
# Processing record 533|presidencia roque saenz pena
# Processing record 534|coahuayana
# Processing record 535|umm kaddadah
# Processing record 536|khandyga
# Processing record 537|pitimbu
# Processing record 538|turbe
# Processing record 539|saint anthony
# Processing record 540|gat
# Processing record 541|palmer
# Processing record 542|sakakah
# Processing record 543|itoigawa
# City not found. skipping.
# Processing record 544|sokolo
# Processing record 545|soe
# Processing record 546|ibimirim
# Processing record 547|bonthe
# Processing record 548|sinnamary
# Processing record 549|donskoye
# City not found. skipping.
# Processing record 550|campbell river
# Processing record 551|kinsale
# Processing record 552|selizharovo
# Processing record 553|sao joao da barra
# Processing record 554|turinsk
# Processing record 555|thai nguyen
# Processing record 556|camacha
# Processing record 557|jining
# Processing record 558|sobolevo
# Processing record 559|phek
# Processing record 560|chilca
# Processing record 561|buncrana
# Processing record 562|berlevag
# Processing record 563|bad salzuflen
# Processing record 564|hokitika
# Processing record 565|enkoping
# City not found. skipping.
# Processing record 566|gubkinskiy
# Processing record 567|college
# Processing record 568|jalu
# Processing record 569|concordia
# Processing record 570|borovskoy
# Processing record 571|tezu
# City not found. skipping.
# Processing record 572|ucluelet
# Processing record 573|birjand
# Processing record 574|maraba
# Processing record 575|whakatane
# City not found. skipping.
# Processing record 576|meulaboh
# Processing record 577|aransas pass

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating city dataframe
city_df = pd.DataFrame({"City":city_name, 
                        "Cloudiness":cloudiness, 
                        "Country":country, 
                        "Date":date, 
                        "Humidity":humidity,
                        "Lat":lat,
                        "Lng":lng,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed
                                         })
city_df = city_df.rename_axis('City ID')

#Exporting data to csv
city_df.to_csv("../output_data/city.csv")

#Displaying dataframe
city_df.head()

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_df.count()

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter( city_df["Lat"], city_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(city_df["Lat"], city_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(city_df["Lat"], city_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(city_df["Lat"], city_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../output_data/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = city_df.loc[city_df["Lat"] >= 0]
southern_hemisphere = city_df.loc[city_df["Lat"] < 0]

# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Function 2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Function 2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Function 2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Function 2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Function 2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Function 2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Function 2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Function 1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Function 2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
